# %% [markdown]
# #01 Import libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #02 Describing variable list and importing the data frame

# %%
#importing the Data frame1
path='/home/ubuntu/Desktop/python_projects'
df=pd.read_csv(os.path.join(path, 'orders.csv'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
vars_list= ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
df=pd.read_csv(os.path.join(path, 'orders.csv'), usecols= vars_list)
df.head(5)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#importing data frame2
df_prods= pd.read_csv(os.path.join(path, 'products.csv'), index_col= False)

# %%
# reviewing some rows of the Data frame
# print the first 20 rows
print("First 20 rows:")
display(df.head(20))
# Out:
# First 20 rows:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
# 11   2168274        2             1          2                 11
# 12   1501582        2             2          5                 10
# ...

# %%
# print the last 35 rows
print("Last 35 rows:")
display(df.tail(35))
# Out:
# Last 35 rows:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 3421048    726186   206208            30          0                 16
# 3421049   2523609   206208            31          4                 11
# 3421050    756221   206208            32          6                 18
# 3421051   2254244   206208            33          6                 13
# 3421052   2017995   206208            34          6                 15
# 3421053   2789700   206208            35          3                 22
# 3421054    844592   206208            36          6                 15
# 3421055   1541132   206208            37          2                 12
# 3421056   2808240   206208            38          0                 15
# 3421057   3027766   206208            39          2                 14
# 3421058   3356245   206208            40          5                  9
# 3421059    442304   206208            41          2                 14
# ...

# %%
#names of the columns of the Products dataframe
df_prods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49693 entries, 0 to 49692
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49693 non-null  int64
#  1   product_name   49677 non-null  object
#  2   aisle_id       49693 non-null  int64
#  3   department_id  49693 non-null  int64
#  4   prices         49693 non-null  float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.9+ MB

# %%
# number of rows and columns of Products dataframe
print('numers of rows and columns are:') 
display(df_prods.shape)
# Out:
# numers of rows and columns are:
# (49693, 5)

# %%
df_prods.describe()
# Out:
#          product_id      aisle_id  department_id        prices
# count  49693.000000  49693.000000   49693.000000  49693.000000
# mean   24844.345139     67.770249      11.728433      9.994136
# std    14343.717401     38.316774       5.850282    453.519686
# min        1.000000      1.000000       1.000000      1.000000
# 25%    12423.000000     35.000000       7.000000      4.100000
# 50%    24845.000000     69.000000      13.000000      7.100000
# 75%    37265.000000    100.000000      17.000000     11.200000
# max    49688.000000    134.000000      21.000000  99999.000000

# %% [markdown]
# # brief descriptive analysis
# maximum value of the “aisle_id” column: 134.000000
# The data type of the “department_id” column: int64
