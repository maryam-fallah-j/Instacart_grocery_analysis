# %% [markdown]
# # 01 importing libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 importing each data set

# %%
ords_prods_combined = pd.read_pickle('orders_products_combined.pkl')

# %%
ords_prods_combined.shape
# Out:
# (32434489, 11)

# %%
ords_prods_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# ...

# %% [markdown]
# #data set ords_prods_combined is the same size as exported already:32434489, 11

# %%
prods_checked = pd.read_csv('products_checked.csv', index_col= 0)

# %%
prods_checked.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_merged= ords_prods_combined.merge(prods_checked, on='product_id', indicator='merge_source')

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged.shape
# Out:
# (32404859, 16)

# %%
df_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge                             product_name  aisle_id  \
# ...

# %%
# df_merged2= ords_prods_combined.merge(prods_checked, on='product_id',how= 'outer', indicator='merge_source')
# I could not run this line of code, despite I checked the availability of enough space in my system and everything was OK, 
# this line of code was broke several times and never ran correctly.

# %%
df_merged.to_pickle('ords_prods_merge.pkl')
