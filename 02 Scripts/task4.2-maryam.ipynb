# %% [markdown]
# #01.Importing Libraries

# %%
#import libraries
import pandas as PN
import numpy as NP
import os

# %% [markdown]
# #02. Python Data types

# %%
# integer-1
x=10
y= 10
print(x*y)
# Out:
# 100

# %%
#integer-2
a=10
r=pow(a, 2)
print(r)
# Out:
# 100

# %%
#integer-3
b=1000
c=10
d=b/c
print(int (d))
# Out:
# 100

# %%
#Floating-point variables-1
x1=124695.253
y1=x/298.523
print('The result is', y1)
# Out:
# The result is 417.7073558821263

# %%
#Floating-point variables-2
v1= 59800.986
v2= 941.65
v3=v1/v2
print('The floating numbers division is', v3)
# Out:
# The floating numbers division is 63.50659586895343

# %%
#strings_word
A='Napoleon '
B= 'Bonaparte'
C= A + B
print('The most famous French general was', C)
# Out:
# The most famous French general was Napoleon Bonaparte

# %%
#String_sentences_1
A1 = 'Old Mc Donal has a farm'
B1 = 'Ee, i, ee, i, o'
C1 = 'And on his farm he had some cows'

result = ' '.join([A1, B1, C1, B1, B1])
print(result)
# Out:
# Old Mc Donal has a farm Ee, i, ee, i, o And on his farm he had some cows Ee, i, ee, i, o Ee, i, ee, i, o

# %%
#String_sentences_2
st1= 'A famouse quote from Harry Potter stories: '
st2= '"It is our choices, Harry, that show what we truly are, far more than our abilities"'
st3= 'Albus Dumbledore'
st4= '\n'.join([st1, st2,st3])
print(st4)
# Out:
# A famouse quote from Harry Potter stories:
# "It is our choices, Harry, that show what we truly are, far more than our abilities"
# Albus Dumbledore
